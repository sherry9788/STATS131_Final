# %% [markdown]
# # Importing Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')
df.shape
# Out:
# (16719, 16)

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# # Looking at the variables

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %% [markdown]
# ## 1. Name column

# %%
df.groupby(['Name']).count()
# Out:
#                                                Platform  Year_of_Release  \
# Name
#  Beyblade Burst                                       1                1
#  Fire Emblem Fates                                    1                1
#  Frozen: Olaf's Quest                                 2                2
#  Haikyu!! Cross Team Match!                           1                1
#  Tales of Xillia 2                                    1                1
# '98 Koshien                                           1                1
# .hack//G.U. Vol.1//Rebirth                            1                1
# .hack//G.U. Vol.2//Reminisce                          1                1
# .hack//G.U. Vol.2//Reminisce (jp sales)               1                1
# .hack//G.U. Vol.3//Redemption                         1                1
# .hack//Infection Part 1                               1                1
# .hack//Link                                           1                1
# ...

# %%
df.loc[(df.Name=="007: Quantum of Solace")]
# Out:
#                          Name Platform  Year_of_Release   Genre   Publisher  \
# 1285   007: Quantum of Solace     X360           2008.0  Action  Activision
# 1785   007: Quantum of Solace      PS3           2008.0  Action  Activision
# 3120   007: Quantum of Solace      Wii           2008.0  Action  Activision
# 4475   007: Quantum of Solace      PS2           2008.0  Action  Activision
# 9508   007: Quantum of Solace       DS           2008.0  Action  Activision
# 14660  007: Quantum of Solace       PC           2008.0  Action  Activision
#
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 1285       0.82      0.51      0.01         0.14          1.48          65.0
# 1785       0.43      0.51      0.02         0.19          1.14          65.0
# 3120       0.29      0.28      0.01         0.07          0.65          54.0
# 4475       0.17      0.00      0.00         0.26          0.43           NaN
# ...

# %%
df.loc[(df.Name=="007: The World is not Enough")]
# Out:
#                               Name Platform  Year_of_Release   Genre  \
# 1204  007: The World is not Enough      N64           2000.0  Action
# 2243  007: The World is not Enough       PS           2000.0  Action
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 1204  Electronic Arts      1.13      0.38      0.02         0.03
# 2243  Electronic Arts      0.51      0.35      0.00         0.06
#
#       Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 1204          1.55           NaN           NaN        NaN         NaN
# 2243          0.92          61.0          11.0        6.7        44.0
#
#                     Developer Rating
# 1204                      NaN    NaN
# 2243  Black Ops Entertainment      T

# %% [markdown]
# ## 2. Platform and Genre columns

# %%
df.Platform.unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df.Genre.unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', nan], dtype=object)

# %%
df.groupby(['Platform']).count()
# Out:
#           Name  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# Platform
# 2600       133              116    133        133       133       133
# 3DO          3                3      3          3         3         3
# 3DS        520              512    520        519       520       520
# DC          52               52     52         52        52        52
# DS        2152             2122   2152       2147      2152      2152
# GB          98               97     98         98        98        98
# GBA        822              811    822        796       822       822
# GC         556              542    556        556       556       556
# GEN         27               29     27         29        29        29
# GG           1                1      1          1         1         1
# N64        319              316    319        319       319       319
# NES         98               98     98         98        98        98
# ...

# %%
df.groupby(['Genre']).count()
# Out:
#               Name  Platform  Year_of_Release  Publisher  NA_Sales  EU_Sales  \
# Genre
# Action        3370      3370             3308       3364      3370      3370
# Adventure     1303      1303             1293       1299      1303      1303
# Fighting       849       849              837        847       849       849
# Misc          1750      1750             1721       1723      1750      1750
# Platform       888       888              878        887       888       888
# Puzzle         580       580              569        580       580       580
# Racing        1249      1249             1226       1248      1249      1249
# Role-Playing  1500      1500             1483       1499      1500      1500
# Shooter       1323      1323             1296       1321      1323      1323
# Simulation     874       874              858        870       874       874
# Sports        2348      2348             2306       2345      2348      2348
# ...

# %%
df.groupby(['Platform','Genre']).count().unstack()
# Out:
#            Name                                                                \
# Genre    Action Adventure Fighting   Misc Platform Puzzle Racing Role-Playing
# Platform
# 2600       61.0       2.0      2.0    5.0      9.0   11.0    6.0          NaN
# 3DO         NaN       1.0      NaN    NaN      NaN    1.0    NaN          NaN
# 3DS       188.0      38.0     14.0   54.0     28.0   20.0   11.0         88.0
# DC          3.0      11.0     12.0    NaN      2.0    NaN    6.0          4.0
# DS        340.0     238.0     36.0  391.0     91.0  236.0   67.0        200.0
# GB          6.0       5.0      NaN    8.0     19.0   15.0    2.0         21.0
# GBA       167.0      38.0     23.0  110.0    142.0   41.0   64.0         73.0
# GC        101.0      20.0     42.0   36.0     73.0   13.0   63.0         27.0
# GEN         3.0       2.0      5.0    1.0      7.0    NaN    1.0          3.0
# GG          NaN       NaN      NaN    NaN      1.0    NaN    NaN          NaN
# ...

# %% [markdown]
# ## 3. Developer

# %%
df.groupby(['Developer']).count()
# Out:
#                                        Name  Platform  Year_of_Release  Genre  \
# Developer
# 10tacle Studios                           1         1                1      1
# 10tacle Studios, Fusionsphere Systems     2         2                2      2
# 1C, 1C Company                            2         2                2      2
# 1C, Ino-Co, 1C Company                    2         2                1      2
# 1C, Various, 1C Company                   1         1                1      1
# 1C: Maddox Games                          2         2                2      2
# 1C:Ino-Co                                 2         2                2      2
# 1st Playable Productions                 12        12               10     12
# 2015                                      1         1                1      1
# 2D Boy                                    1         1                1      1
# 2K Australia                              3         3                3      3
# ...

# %% [markdown]
# # Cleaning data

# %%
df.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
dfnona = df.dropna()
dfnona.head()
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 2         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 3      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 6  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 7               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 6     11.28      9.14      6.50         2.88         29.80          89.0
# 7     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
dfnona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6825 entries, 0 to 16706
# Data columns (total 16 columns):
# Name               6825 non-null object
# Platform           6825 non-null object
# Year_of_Release    6825 non-null float64
# Genre              6825 non-null object
# Publisher          6825 non-null object
# NA_Sales           6825 non-null float64
# EU_Sales           6825 non-null float64
# JP_Sales           6825 non-null float64
# Other_Sales        6825 non-null float64
# Global_Sales       6825 non-null float64
# Critic_Score       6825 non-null float64
# Critic_Count       6825 non-null float64
# User_Score         6825 non-null object
# User_Count         6825 non-null float64
# Developer          6825 non-null object
# Rating             6825 non-null object
# dtypes: float64(9), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# # Finding relation between variables

# %%
sns.barplot(dfnona.Genre, df.Global_Sales, alpha=0.8)

# %%
dfnona.groupby(['Genre']).Global_Sales.mean()
# Out:
# Genre
# Action          0.738135
# Adventure       0.325605
# Fighting        0.661243
# Misc            1.084010
# Platform        0.937469
# Puzzle          0.668644
# Racing          0.819656
# Role-Playing    0.704171
# Shooter         0.945000
# Simulation      0.682492
# Sports          0.884252
# Strategy        0.260712
# Name: Global_Sales, dtype: float64

# %%
sns.barplot(dfnona.Genre, df.NA_Sales, alpha=0.8)

# %%
sns.barplot(dfnona.Platform, df.NA_Sales, alpha=0.8)

# %%
sns.barplot(dfnona.Platform, df.Global_Sales, alpha=0.8)

# %%
dfnona.groupby(['Platform']).Global_Sales.mean()
# Out:
# Platform
# 3DS     0.795032
# DC      0.325000
# DS      0.823987
# GBA     0.555907
# GC      0.458103
# PC      0.287435
# PS      1.377000
# PS2     0.829798
# PS3     1.019896
# PS4     1.016862
# PSP     0.481846
# PSV     0.261695
# Wii     1.375741
# WiiU    0.742472
# X360    0.994522
# XB      0.375345
# XOne    0.814906
# Name: Global_Sales, dtype: float64

# %%
sns.barplot(dfnona.Rating, df.Global_Sales, alpha=0.8)

# %%
sns.barplot(dfnona.Year_of_Release, df.Global_Sales, alpha=0.8)

# %%
sns.barplot(dfnona.Platform, dfnona.User_Score.astype(float), alpha=0.8)

# %%
sns.barplot(dfnona.Genre, dfnona.User_Score.astype(float), alpha=0.8)

# %%
dfnona.groupby(['Year_of_Release','Genre']).count()
# Out:
#                               Name  Platform  Publisher  NA_Sales  EU_Sales  \
# Year_of_Release Genre
# 1985.0          Simulation       1         1          1         1         1
# 1988.0          Simulation       1         1          1         1         1
# 1992.0          Shooter          1         1          1         1         1
# 1994.0          Fighting         1         1          1         1         1
# 1996.0          Action           3         3          3         3         3
#                 Fighting         1         1          1         1         1
#                 Misc             1         1          1         1         1
#                 Puzzle           1         1          1         1         1
#                 Role-Playing     1         1          1         1         1
# 1997.0          Action           1         1          1         1         1
#                 Fighting         1         1          1         1         1
# ...

# %%
dfnona.groupby(['Year_of_Release','Platform']).count()
# Out:
#                           Name  Genre  Publisher  NA_Sales  EU_Sales  \
# Year_of_Release Platform
# 1985.0          PC           1      1          1         1         1
# 1988.0          PC           1      1          1         1         1
# 1992.0          PC           1      1          1         1         1
# 1994.0          PS           1      1          1         1         1
# 1996.0          PC           2      2          2         2         2
#                 PS           5      5          5         5         5
# 1997.0          PC           1      1          1         1         1
#                 PS          12     12         12        12        12
# 1998.0          PC           3      3          3         3         3
#                 PS          22     22         22        22        22
# 1999.0          DC           3      3          3         3         3
#                 PC           2      2          2         2         2
# ...

# %%
len(dfnona.Publisher.unique())
# Out:
# 262

# %%
len(dfnona.Developer.unique())
# Out:
# 1289

# %%
dfnona.groupby(['Publisher','Developer']).count()
# Out:
#                                                          Name  Platform  \
# Publisher              Developer
# 10TACLE Studios        WideScreen Games                     1         1
# 1C Company             Katauri Interactive                  1         1
#                        THQ, 1C, 1C Company                  1         1
# 2D Boy                 2D Boy                               1         1
# 3DO                    3DO                                 15        15
# 505 Games              505 Games                            2         2
#                        Acquire                              1         1
#                        Arc System Works                     3         3
#                        Artech Studios                       1         1
#                        Artificial Mind and Movement         2         2
#                        Barnhouse Effect                     1         1
#                        BeeWorks                             1         1
# ...

# %% [markdown]
# ## 505 Games

# %%
df505 = dfnona.loc[dfnona.Publisher=='505 Games']
df505.head()
# Out:
#                                      Name Platform  Year_of_Release  \
# 156                          Cooking Mama       DS           2006.0
# 360   Cooking Mama 2: Dinner With Friends       DS           2007.0
# 501                Cooking Mama: Cook Off      Wii           2007.0
# 669                         Zumba Fitness     X360           2010.0
# 1432                       Gardening Mama       DS           2009.0
#
#            Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 156   Simulation  505 Games      3.07      1.91      0.07         0.57
# 360   Simulation  505 Games      1.60      1.49      0.10         0.39
# 501   Simulation  505 Games      1.41      1.12      0.05         0.30
# 669       Sports  505 Games      1.74      0.45      0.00         0.18
# 1432      Puzzle  505 Games      0.79      0.42      0.01         0.13
#
#       Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# ...

# %%
sns.barplot(df505.Genre, df505.Global_Sales, alpha=0.8)

# %%
df505.groupby(['Developer']).Global_Sales.mean()
# Out:
# Developer
# 505 Games                           0.080000
# Acquire                             0.080000
# Arc System Works                    0.076667
# Artech Studios                      0.170000
# Artificial Mind and Movement        0.415000
# Barnhouse Effect                    0.010000
# BeeWorks                            0.090000
# Best Way                            0.030000
# Blitz Games                         0.110000
# Bohemia Interactive                 0.140000
# Buka Entertainment, Targem Games    0.050000
# Cooking Mama Limited                0.740000
# Crave                               0.140000
# DiP Interactive                     0.060000
# Dimps Corporation                   0.100000
# Doublesix                           0.070000
# Eighting, Takara Tomy               0.180000
# Engine Software                     0.297500
# From Software                       0.175000
# Gaijin Entertainment                0.595000
# Gust                                0.100000
# ...

# %%
df505.groupby(['Genre','Rating']).Global_Sales.mean()
# Out:
# Genre         Rating
# Action        E         0.030000
#               E10+      0.125000
#               M         0.050000
#               T         0.271250
# Adventure     E10+      0.090000
#               T         0.090000
# Fighting      E10+      0.100000
#               M         0.100000
#               T         0.092000
# Misc          E10+      0.050000
#               T         0.120000
# Puzzle        E         0.536667
# Racing        E         0.040000
# Role-Playing  E         0.030000
#               E10+      0.140000
#               T         0.125714
# Shooter       M         0.409000
#               T         0.120000
# Simulation    E         2.716000
#               E10+      0.290000
#               T         0.266250
# Sports        E         0.516250
#               E10+      0.180000
#               T         0.090000
# Strategy      E10+      0.090000
#               M         0.030000
#               T         0.080000
# ...

# %%
df505.groupby(['Developer','Rating']).Global_Sales.mean()
# Out:
# Developer                         Rating
# 505 Games                         T         0.080000
# Acquire                           M         0.080000
# Arc System Works                  T         0.076667
# Artech Studios                    T         0.170000
# Artificial Mind and Movement      T         0.415000
# Barnhouse Effect                  T         0.010000
# BeeWorks                          E10+      0.090000
# Best Way                          M         0.030000
# Blitz Games                       E         0.110000
# Bohemia Interactive               M         0.140000
# Buka Entertainment, Targem Games  M         0.050000
# Cooking Mama Limited              E         0.740000
# Crave                             T         0.140000
# DiP Interactive                   E10+      0.060000
# Dimps Corporation                 E10+      0.100000
# Doublesix                         T         0.070000
# Eighting, Takara Tomy             E10+      0.180000
# ...
